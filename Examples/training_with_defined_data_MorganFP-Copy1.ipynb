# %%
import os
import sys
sys.path.append('../')
import numpy as np

from MolRep import MolRep
from MolRep.Utils.logger import Logger
from MolRep.Utils.config_from_dict import Config
from MolRep.Experiments.experiments import EndToEndExperiment

# %%
MODEL_CONFIG_DIR = '../MolRep/Configs' # Need to set! The directory of Model Configurations files, such as config_CMPNN.yml.
DATASET_DIR = '../MolRep/Datasets'     # Need to set! The directory of Datasets downloaded from Google Drive.
OUTPUT_DIR = '../Outputs/'

# Output file name
_CONFIG_BASE = 'config_'
_CONFIG_FILENAME = 'config_results.json'

# Args
_FOLDS = 5
MODEL_NAME = 'MorganFP'#'MolecularFingerprint' #'CMPNN'
DATASET_NAME = 'BBBP'

# %%
dataset_config, dataset, model_configurations, model_selector, exp_path = MolRep.construct_dataset(
        dataset_name = DATASET_NAME,
        model_name = MODEL_NAME,
        inner_k = _FOLDS,
        config_dir = MODEL_CONFIG_DIR,
        datasets_dir = DATASET_DIR,
        output_dir=OUTPUT_DIR
)

# %%
config_id = 0  # the idx of model config since there are more than 100 combinations of hyper-parameters.
KFOLD_FOLDER = os.path.join(exp_path, str(_FOLDS) + '_FOLD_MS')
exp_config_name = os.path.join(KFOLD_FOLDER, _CONFIG_BASE + str(config_id + 1))
config_filename = os.path.join(exp_config_name, _CONFIG_FILENAME)
if not os.path.exists(exp_config_name):
    os.makedirs(exp_config_name)

# %%
config = model_configurations[config_id]

# model configs could be change
# for example:
# config['device'] = 'cpu' or config['batch_size'] = 32

logger = Logger(str(os.path.join(exp_config_name, 'experiment.log')), mode='w')
logger.log('Configuration: ' + str(config))
# Out:
# Configuration: {'model': 'MorganFP', 'device': 'cuda', 'batch_size': 32, 'learning_rate': 0.01, 'l2': 0.0, 'num_epochs': 50, 'num_lrs': 1, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'gradient_clipping': None, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': True}}, 'shuffle': True, 'hidden_units': 128}

# %%
k_fold_dict = {
    'config': config,
    'folds': [{} for _ in range(_FOLDS)],
    'avg_TR_score': 0.,
    'avg_VL_score': 0.,
    'std_TR_score': 0.,
    'std_VL_score': 0.
}

# %%
dataset_getter = MolRep.construct_dataloader(dataset)
for k in range(_FOLDS):
    logger.log(f"Training in Fold: {k+1}")
    dataset_getter.set_inner_k(k)

    fold_exp_folder = os.path.join(exp_config_name, 'FOLD_' + str(k + 1))
    # Create the experiment object which will be responsible for running a specific experiment
    experiment = EndToEndExperiment(config, dataset_config, fold_exp_folder)

    model_path = os.path.join(fold_exp_folder, f"{MODEL_NAME}_{DATASET_NAME}_fold_{k}.pt")
    training_score, validation_score, validation_loss = experiment.run_valid(dataset_getter, logger, other={'model_path': model_path})

    # print('training_score:', training_score, 'validation_score:',validation_score)
    logger.log(str(k+1) + ' split, TR Score: ' + str(training_score) +
                ' VL Score: ' + str(validation_score))

    k_fold_dict['folds'][k]['TR_score'] = training_score
    k_fold_dict['folds'][k]['VL_score'] = validation_score

tr_scores = np.array([k_fold_dict['folds'][k]['TR_score'] for k in range(_FOLDS)])
vl_scores = np.array([k_fold_dict['folds'][k]['VL_score'] for k in range(_FOLDS)])

k_fold_dict['avg_TR_score'] = tr_scores.mean()
k_fold_dict['std_TR_score'] = tr_scores.std()
k_fold_dict['avg_VL_score'] = vl_scores.mean()
k_fold_dict['std_VL_score'] = vl_scores.std()


log_str = f"TR avg is %.4f std is %.4f; VL avg is %.4f std is %.4f" % (
            k_fold_dict['avg_TR_score'], k_fold_dict['std_TR_score'], k_fold_dict['avg_VL_score'], k_fold_dict['std_VL_score']
        )
logger.log(log_str)
# Out:
# Training in Fold: 1
# [TRAIN] Epoch: 1, train loss: 0.693333 train auc: 0.426080
# [TRAIN] Metric:{'auc': 0.42608011672311275}
# [VALID] Epoch: 1, valid loss: 0.573258 valid auc: 0.483048
# [VALID] Metric:{'auc': 0.48304828783931736}
# [TEST] Metric:None
# - Elapsed time: 3.71s , Time estimation in a fold: 3.09min
# [TRAIN] Epoch: 10, train loss: 0.559423 train auc: 0.768928
# [TRAIN] Metric:{'auc': 0.768927769422946}
# [VALID] Epoch: 10, valid loss: 0.541163 valid auc: 0.738098
# [VALID] Metric:{'auc': 0.7380979348359572}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 20, train loss: 0.436790 train auc: 0.878079
# [TRAIN] Metric:{'auc': 0.8780785517204841}
# [VALID] Epoch: 20, valid loss: 0.515360 valid auc: 0.788349
# [VALID] Metric:{'auc': 0.7883490013969117}
# [TEST] Metric:None
# - Elapsed time: 0.99s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 30, train loss: 0.366541 train auc: 0.934496
# [TRAIN] Metric:{'auc': 0.9344960813801367}
# [VALID] Epoch: 30, valid loss: 0.504042 valid auc: 0.810813
# [VALID] Metric:{'auc': 0.8108128515875712}
# [TEST] Metric:None
# - Elapsed time: 1.92s , Time estimation in a fold: 1.60min
# [TRAIN] Epoch: 40, train loss: 0.312893 train auc: 0.967925
# [TRAIN] Metric:{'auc': 0.9679245782847734}
# [VALID] Epoch: 40, valid loss: 0.498045 valid auc: 0.819383
# [VALID] Metric:{'auc': 0.8193830935930834}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 50, train loss: 0.271271 train auc: 0.984825
# [TRAIN] Metric:{'auc': 0.9848247726874437}
# [VALID] Epoch: 50, valid loss: 0.494857 valid auc: 0.816948
# [VALID] Metric:{'auc': 0.8169479367236757}
# [TEST] Metric:None
# - Elapsed time: 1.29s , Time estimation in a fold: 1.08min
# 1 split, TR Score: 0.9848247726874437 VL Score: 0.8169479367236757
# Training in Fold: 2
# [TRAIN] Epoch: 1, train loss: 0.666894 train auc: 0.583398
# [TRAIN] Metric:{'auc': 0.5833975228942767}
# [VALID] Epoch: 1, valid loss: 0.563568 valid auc: 0.700193
# [VALID] Metric:{'auc': 0.7001925472873485}
# [TEST] Metric:None
# - Elapsed time: 1.01s , Time estimation in a fold: 0.84min
# [TRAIN] Epoch: 10, train loss: 0.410320 train auc: 0.903123
# [TRAIN] Metric:{'auc': 0.9031226693076086}
# [VALID] Epoch: 10, valid loss: 0.510193 valid auc: 0.803224
# [VALID] Metric:{'auc': 0.8032242232038358}
# [TEST] Metric:None
# - Elapsed time: 1.75s , Time estimation in a fold: 1.46min
# [TRAIN] Epoch: 20, train loss: 0.315888 train auc: 0.966887
# [TRAIN] Metric:{'auc': 0.9668873564904817}
# [VALID] Epoch: 20, valid loss: 0.497839 valid auc: 0.822026
# [VALID] Metric:{'auc': 0.8220258994978669}
# [TEST] Metric:None
# - Elapsed time: 1.24s , Time estimation in a fold: 1.03min
# [TRAIN] Epoch: 30, train loss: 0.262954 train auc: 0.986638
# [TRAIN] Metric:{'auc': 0.9866383825045748}
# [VALID] Epoch: 30, valid loss: 0.493826 valid auc: 0.819987
# [VALID] Metric:{'auc': 0.8199871635141768}
# [TEST] Metric:None
# - Elapsed time: 2.00s , Time estimation in a fold: 1.67min
# [TRAIN] Epoch: 40, train loss: 0.231012 train auc: 0.993024
# [TRAIN] Metric:{'auc': 0.9930237154955638}
# [VALID] Epoch: 40, valid loss: 0.492350 valid auc: 0.812587
# [VALID] Metric:{'auc': 0.8125873069807831}
# [TEST] Metric:None
# - Elapsed time: 1.48s , Time estimation in a fold: 1.23min
# [TRAIN] Epoch: 50, train loss: 0.211600 train auc: 0.995385
# [TRAIN] Metric:{'auc': 0.9953854837855132}
# [VALID] Epoch: 50, valid loss: 0.491804 valid auc: 0.805414
# [VALID] Metric:{'auc': 0.8054139766677993}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# 2 split, TR Score: 0.9950788003276726 VL Score: 0.806961905840601
# Training in Fold: 3
# [TRAIN] Epoch: 1, train loss: 0.693161 train auc: 0.499148
# [TRAIN] Metric:{'auc': 0.4991482147151003}
# [VALID] Epoch: 1, valid loss: 0.573342 valid auc: 0.500000
# [VALID] Metric:{'auc': 0.5}
# [TEST] Metric:None
# - Elapsed time: 1.00s , Time estimation in a fold: 0.83min
# [TRAIN] Epoch: 10, train loss: 0.693057 train auc: 0.500406
# [TRAIN] Metric:{'auc': 0.5004055150040552}
# [VALID] Epoch: 10, valid loss: 0.573342 valid auc: 0.500000
# [VALID] Metric:{'auc': 0.5}
# [TEST] Metric:None
# - Elapsed time: 0.97s , Time estimation in a fold: 0.81min
# [TRAIN] Epoch: 20, train loss: 0.346322 train auc: 0.944700
# [TRAIN] Metric:{'auc': 0.9447001838062984}
# [VALID] Epoch: 20, valid loss: 0.499764 valid auc: 0.808585
# [VALID] Metric:{'auc': 0.8085853437535395}
# [TEST] Metric:None
# - Elapsed time: 0.99s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 30, train loss: 0.249418 train auc: 0.989377
# [TRAIN] Metric:{'auc': 0.9893771371048267}
# [VALID] Epoch: 30, valid loss: 0.493101 valid auc: 0.808283
# [VALID] Metric:{'auc': 0.8082833087929928}
# [TEST] Metric:None
# - Elapsed time: 1.06s , Time estimation in a fold: 0.88min
# [TRAIN] Epoch: 40, train loss: 0.215572 train auc: 0.994513
# [TRAIN] Metric:{'auc': 0.9945133208622188}
# [VALID] Epoch: 40, valid loss: 0.492051 valid auc: 0.801752
# [VALID] Metric:{'auc': 0.8017518027711708}
# [TEST] Metric:None
# - Elapsed time: 1.27s , Time estimation in a fold: 1.06min
# [TRAIN] Epoch: 50, train loss: 0.199416 train auc: 0.995556
# [TRAIN] Metric:{'auc': 0.9955556370661092}
# [VALID] Epoch: 50, valid loss: 0.491273 valid auc: 0.796164
# [VALID] Metric:{'auc': 0.796164156001057}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# 3 split, TR Score: 0.9958663960516289 VL Score: 0.798051874504474
# Training in Fold: 4
# [TRAIN] Epoch: 1, train loss: 0.636830 train auc: 0.589845
# [TRAIN] Metric:{'auc': 0.5898450076823696}
# [VALID] Epoch: 1, valid loss: 0.551805 valid auc: 0.716767
# [VALID] Metric:{'auc': 0.7167667157473477}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 10, train loss: 0.341065 train auc: 0.950860
# [TRAIN] Metric:{'auc': 0.9508603438930254}
# [VALID] Epoch: 10, valid loss: 0.499421 valid auc: 0.821837
# [VALID] Metric:{'auc': 0.8218371276475251}
# [TEST] Metric:None
# - Elapsed time: 1.97s , Time estimation in a fold: 1.64min
# [TRAIN] Epoch: 20, train loss: 0.256063 train auc: 0.988139
# [TRAIN] Metric:{'auc': 0.9881391955723469}
# [VALID] Epoch: 20, valid loss: 0.492938 valid auc: 0.818043
# [VALID] Metric:{'auc': 0.8180428134556575}
# [TEST] Metric:None
# - Elapsed time: 1.91s , Time estimation in a fold: 1.59min
# [TRAIN] Epoch: 30, train loss: 0.218881 train auc: 0.994651
# [TRAIN] Metric:{'auc': 0.9946508699213832}
# [VALID] Epoch: 30, valid loss: 0.490937 valid auc: 0.810058
# [VALID] Metric:{'auc': 0.8100577641862046}
# [TEST] Metric:None
# - Elapsed time: 1.99s , Time estimation in a fold: 1.66min
# [TRAIN] Epoch: 40, train loss: 0.200296 train auc: 0.995127
# [TRAIN] Metric:{'auc': 0.9951266877779}
# [VALID] Epoch: 40, valid loss: 0.490105 valid auc: 0.804017
# [VALID] Metric:{'auc': 0.8040170649752709}
# [TEST] Metric:None
# - Elapsed time: 1.47s , Time estimation in a fold: 1.22min
# [TRAIN] Epoch: 50, train loss: 0.190958 train auc: 0.995498
# [TRAIN] Metric:{'auc': 0.9954975607966842}
# [VALID] Epoch: 50, valid loss: 0.490079 valid auc: 0.798429
# [VALID] Metric:{'auc': 0.7984294182051572}
# [TEST] Metric:None
# - Elapsed time: 0.99s , Time estimation in a fold: 0.83min
# 4 split, TR Score: 0.9954975607966842 VL Score: 0.7984294182051572
# Training in Fold: 5
# [TRAIN] Epoch: 1, train loss: 0.693054 train auc: 0.498203
# [TRAIN] Metric:{'auc': 0.4982026922935847}
# [VALID] Epoch: 1, valid loss: 0.573317 valid auc: 0.501416
# [VALID] Metric:{'auc': 0.5014157888775626}
# [TEST] Metric:None
# - Elapsed time: 0.96s , Time estimation in a fold: 0.80min
# [TRAIN] Epoch: 10, train loss: 0.337810 train auc: 0.952717
# [TRAIN] Metric:{'auc': 0.9527167467507855}
# [VALID] Epoch: 10, valid loss: 0.499706 valid auc: 0.818817
# [VALID] Metric:{'auc': 0.8188167780420583}
# [TEST] Metric:None
# - Elapsed time: 0.97s , Time estimation in a fold: 0.81min
# [TRAIN] Epoch: 20, train loss: 0.250751 train auc: 0.989030
# [TRAIN] Metric:{'auc': 0.9890296983701966}
# [VALID] Epoch: 20, valid loss: 0.493033 valid auc: 0.816004
# [VALID] Metric:{'auc': 0.8160040774719673}
# [TEST] Metric:None
# - Elapsed time: 1.15s , Time estimation in a fold: 0.95min
# [TRAIN] Epoch: 30, train loss: 0.216007 train auc: 0.994779
# [TRAIN] Metric:{'auc': 0.9947792490432699}
# [VALID] Epoch: 30, valid loss: 0.491724 valid auc: 0.808283
# [VALID] Metric:{'auc': 0.8082833087929928}
# [TEST] Metric:None
# - Elapsed time: 0.97s , Time estimation in a fold: 0.81min
# [TRAIN] Epoch: 40, train loss: 0.198877 train auc: 0.994701
# [TRAIN] Metric:{'auc': 0.9947007951354502}
# [VALID] Epoch: 40, valid loss: 0.490960 valid auc: 0.801941
# [VALID] Metric:{'auc': 0.8019405746215125}
# [TEST] Metric:None
# - Elapsed time: 1.01s , Time estimation in a fold: 0.84min
# [TRAIN] Epoch: 50, train loss: 0.190326 train auc: 0.994700
# [TRAIN] Metric:{'auc': 0.9946997762535303}
# [VALID] Epoch: 50, valid loss: 0.490157 valid auc: 0.798373
# [VALID] Metric:{'auc': 0.7983727866500547}
# [TEST] Metric:None
# - Elapsed time: 2.01s , Time estimation in a fold: 1.68min
# 5 split, TR Score: 0.9946997762535303 VL Score: 0.7983727866500547
# TR avg is 0.9932 std is 0.0042; VL avg is 0.8038 std is 0.0074
