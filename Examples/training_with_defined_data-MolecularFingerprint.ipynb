# %%
import os
import sys
sys.path.append('../')
import numpy as np

from MolRep import MolRep
from MolRep.Utils.logger import Logger
from MolRep.Utils.config_from_dict import Config
from MolRep.Experiments.experiments import EndToEndExperiment

# %%
MODEL_CONFIG_DIR = '../MolRep/Configs' # Need to set! The directory of Model Configurations files, such as config_CMPNN.yml.
DATASET_DIR = '../MolRep/Datasets'     # Need to set! The directory of Datasets downloaded from Google Drive.
OUTPUT_DIR = '../Outputs/'

# Output file name
_CONFIG_BASE = 'config_'
_CONFIG_FILENAME = 'config_results.json'

# Args
_FOLDS = 5
MODEL_NAME = 'MolecularFingerprint' #'CMPNN'
DATASET_NAME = 'BBBP'

# %%
dataset_config, dataset, model_configurations, model_selector, exp_path = MolRep.construct_dataset(
        dataset_name = DATASET_NAME,
        model_name = MODEL_NAME,
        inner_k = _FOLDS,
        config_dir = MODEL_CONFIG_DIR,
        datasets_dir = DATASET_DIR,
        output_dir=OUTPUT_DIR
)

# %%
config_id = 0  # the idx of model config since there are more than 100 combinations of hyper-parameters.
KFOLD_FOLDER = os.path.join(exp_path, str(_FOLDS) + '_FOLD_MS')
exp_config_name = os.path.join(KFOLD_FOLDER, _CONFIG_BASE + str(config_id + 1))
config_filename = os.path.join(exp_config_name, _CONFIG_FILENAME)
if not os.path.exists(exp_config_name):
    os.makedirs(exp_config_name)

# %%
config = model_configurations[config_id]

# model configs could be change
# for example:
# config['device'] = 'cpu' or config['batch_size'] = 32

logger = Logger(str(os.path.join(exp_config_name, 'experiment.log')), mode='w')
logger.log('Configuration: ' + str(config))
# Out:
# Configuration: {'model': 'MolecularFingerprint', 'device': 'cuda', 'batch_size': 32, 'learning_rate': 0.01, 'l2': 0.0, 'num_epochs': 50, 'num_lrs': 1, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'gradient_clipping': None, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': True}}, 'shuffle': True, 'hidden_units': 128}

# %%
k_fold_dict = {
    'config': config,
    'folds': [{} for _ in range(_FOLDS)],
    'avg_TR_score': 0.,
    'avg_VL_score': 0.,
    'std_TR_score': 0.,
    'std_VL_score': 0.
}

# %%
dataset_getter = MolRep.construct_dataloader(dataset)
for k in range(_FOLDS):
    logger.log(f"Training in Fold: {k+1}")
    dataset_getter.set_inner_k(k)

    fold_exp_folder = os.path.join(exp_config_name, 'FOLD_' + str(k + 1))
    # Create the experiment object which will be responsible for running a specific experiment
    experiment = EndToEndExperiment(config, dataset_config, fold_exp_folder)

    model_path = os.path.join(fold_exp_folder, f"{MODEL_NAME}_{DATASET_NAME}_fold_{k}.pt")
    training_score, validation_score, validation_loss = experiment.run_valid(dataset_getter, logger, other={'model_path': model_path})

    # print('training_score:', training_score, 'validation_score:',validation_score)
    logger.log(str(k+1) + ' split, TR Score: ' + str(training_score) +
                ' VL Score: ' + str(validation_score))

    k_fold_dict['folds'][k]['TR_score'] = training_score
    k_fold_dict['folds'][k]['VL_score'] = validation_score

tr_scores = np.array([k_fold_dict['folds'][k]['TR_score'] for k in range(_FOLDS)])
vl_scores = np.array([k_fold_dict['folds'][k]['VL_score'] for k in range(_FOLDS)])

k_fold_dict['avg_TR_score'] = tr_scores.mean()
k_fold_dict['std_TR_score'] = tr_scores.std()
k_fold_dict['avg_VL_score'] = vl_scores.mean()
k_fold_dict['std_VL_score'] = vl_scores.std()


log_str = f"TR avg is %.4f std is %.4f; VL avg is %.4f std is %.4f" % (
            k_fold_dict['avg_TR_score'], k_fold_dict['std_TR_score'], k_fold_dict['avg_VL_score'], k_fold_dict['std_VL_score']
        )
logger.log(log_str)
# Out:
# Training in Fold: 1
# [TRAIN] Epoch: 1, train loss: 0.704642 train auc: 0.760567
# [TRAIN] Metric:{'auc': 0.7605668243895878}
# [VALID] Epoch: 1, valid loss: 0.570776 valid auc: 0.694171
# [VALID] Metric:{'auc': 0.6941707252614491}
# [TEST] Metric:None
# - Elapsed time: 3.89s , Time estimation in a fold: 3.24min
# [TRAIN] Epoch: 10, train loss: 0.556775 train auc: 0.638409
# [TRAIN] Metric:{'auc': 0.638408995504693}
# [VALID] Epoch: 10, valid loss: 0.539580 valid auc: 0.647997
# [VALID] Metric:{'auc': 0.6479971306678749}
# [TEST] Metric:None
# - Elapsed time: 0.93s , Time estimation in a fold: 0.78min
# [TRAIN] Epoch: 20, train loss: 0.512569 train auc: 0.728960
# [TRAIN] Metric:{'auc': 0.7289600883574401}
# [VALID] Epoch: 20, valid loss: 0.529388 valid auc: 0.712897
# [VALID] Metric:{'auc': 0.7128968928153433}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 30, train loss: 0.478422 train auc: 0.759503
# [TRAIN] Metric:{'auc': 0.759503111665383}
# [VALID] Epoch: 30, valid loss: 0.519378 valid auc: 0.738117
# [VALID] Metric:{'auc': 0.7381168120209914}
# [TEST] Metric:None
# - Elapsed time: 0.92s , Time estimation in a fold: 0.76min
# [TRAIN] Epoch: 40, train loss: 0.456517 train auc: 0.776693
# [TRAIN] Metric:{'auc': 0.7766926685332584}
# [VALID] Epoch: 40, valid loss: 0.511860 valid auc: 0.753143
# [VALID] Metric:{'auc': 0.7531430513081889}
# [TEST] Metric:None
# - Elapsed time: 0.93s , Time estimation in a fold: 0.77min
# [TRAIN] Epoch: 50, train loss: 0.443049 train auc: 0.789050
# [TRAIN] Metric:{'auc': 0.7890496684558235}
# [VALID] Epoch: 50, valid loss: 0.507255 valid auc: 0.770435
# [VALID] Metric:{'auc': 0.7704345527994866}
# [TEST] Metric:None
# - Elapsed time: 0.89s , Time estimation in a fold: 0.74min
# 1 split, TR Score: 0.7898525474085757 VL Score: 0.7635255030769811
# Training in Fold: 2
# [TRAIN] Epoch: 1, train loss: 0.607889 train auc: 0.413601
# [TRAIN] Metric:{'auc': 0.41360085097017935}
# [VALID] Epoch: 1, valid loss: 0.546569 valid auc: 0.411277
# [VALID] Metric:{'auc': 0.41127723033941177}
# [TEST] Metric:None
# - Elapsed time: 1.11s , Time estimation in a fold: 0.92min
# [TRAIN] Epoch: 10, train loss: 0.486647 train auc: 0.757616
# [TRAIN] Metric:{'auc': 0.7576161423500307}
# [VALID] Epoch: 10, valid loss: 0.522753 valid auc: 0.732076
# [VALID] Metric:{'auc': 0.7320761128100578}
# [TEST] Metric:None
# - Elapsed time: 0.94s , Time estimation in a fold: 0.78min
# [TRAIN] Epoch: 20, train loss: 0.444389 train auc: 0.787782
# [TRAIN] Metric:{'auc': 0.787782179347671}
# [VALID] Epoch: 20, valid loss: 0.508841 valid auc: 0.757636
# [VALID] Metric:{'auc': 0.7576358213463209}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 30, train loss: 0.428648 train auc: 0.796042
# [TRAIN] Metric:{'auc': 0.7960422550709754}
# [VALID] Epoch: 30, valid loss: 0.504625 valid auc: 0.779458
# [VALID] Metric:{'auc': 0.7794578472458188}
# [TEST] Metric:None
# - Elapsed time: 1.02s , Time estimation in a fold: 0.85min
# [TRAIN] Epoch: 40, train loss: 0.418272 train auc: 0.806236
# [TRAIN] Metric:{'auc': 0.8062361686779396}
# [VALID] Epoch: 40, valid loss: 0.499139 valid auc: 0.787537
# [VALID] Metric:{'auc': 0.7875372824404425}
# [TEST] Metric:None
# - Elapsed time: 0.96s , Time estimation in a fold: 0.80min
# [TRAIN] Epoch: 50, train loss: 0.409365 train auc: 0.818255
# [TRAIN] Metric:{'auc': 0.818254899803152}
# [VALID] Epoch: 50, valid loss: 0.497658 valid auc: 0.799864
# [VALID] Metric:{'auc': 0.7998640842677539}
# [TEST] Metric:None
# - Elapsed time: 0.97s , Time estimation in a fold: 0.81min
# 2 split, TR Score: 0.8168600504550325 VL Score: 0.7895382640540642
# Training in Fold: 3
# [TRAIN] Epoch: 1, train loss: 0.613424 train auc: 0.458764
# [TRAIN] Metric:{'auc': 0.45876381094442203}
# [VALID] Epoch: 1, valid loss: 0.541621 valid auc: 0.574546
# [VALID] Metric:{'auc': 0.5745460036999284}
# [TEST] Metric:None
# - Elapsed time: 1.23s , Time estimation in a fold: 1.02min
# [TRAIN] Epoch: 10, train loss: 0.467604 train auc: 0.770022
# [TRAIN] Metric:{'auc': 0.770022048604743}
# [VALID] Epoch: 10, valid loss: 0.514008 valid auc: 0.740911
# [VALID] Metric:{'auc': 0.7409106354060483}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 20, train loss: 0.437172 train auc: 0.792915
# [TRAIN] Metric:{'auc': 0.7929153064593039}
# [VALID] Epoch: 20, valid loss: 0.503554 valid auc: 0.770284
# [VALID] Metric:{'auc': 0.7702835353192133}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 30, train loss: 0.423231 train auc: 0.802096
# [TRAIN] Metric:{'auc': 0.8020964514380499}
# [VALID] Epoch: 30, valid loss: 0.502515 valid auc: 0.790973
# [VALID] Metric:{'auc': 0.790972930116661}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 40, train loss: 0.413461 train auc: 0.812769
# [TRAIN] Metric:{'auc': 0.8127692395472904}
# [VALID] Epoch: 40, valid loss: 0.495678 valid auc: 0.796259
# [VALID] Metric:{'auc': 0.7962585419262279}
# [TEST] Metric:None
# - Elapsed time: 0.94s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 50, train loss: 0.404693 train auc: 0.824982
# [TRAIN] Metric:{'auc': 0.8249815582372526}
# [VALID] Epoch: 50, valid loss: 0.494827 valid auc: 0.808529
# [VALID] Metric:{'auc': 0.808528712198437}
# [TEST] Metric:None
# - Elapsed time: 0.96s , Time estimation in a fold: 0.80min
# 3 split, TR Score: 0.8227522445968691 VL Score: 0.796258541926228
# Training in Fold: 4
# [TRAIN] Epoch: 1, train loss: 0.662973 train auc: 0.349741
# [TRAIN] Metric:{'auc': 0.3497414077687709}
# [VALID] Epoch: 1, valid loss: 0.547722 valid auc: 0.412825
# [VALID] Metric:{'auc': 0.4128251595122136}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 10, train loss: 0.474824 train auc: 0.763699
# [TRAIN] Metric:{'auc': 0.763698867410858}
# [VALID] Epoch: 10, valid loss: 0.514706 valid auc: 0.738117
# [VALID] Metric:{'auc': 0.7381168120209914}
# [TEST] Metric:None
# - Elapsed time: 0.93s , Time estimation in a fold: 0.78min
# [TRAIN] Epoch: 20, train loss: 0.440722 train auc: 0.791856
# [TRAIN] Metric:{'auc': 0.791855669262778}
# [VALID] Epoch: 20, valid loss: 0.504046 valid auc: 0.771397
# [VALID] Metric:{'auc': 0.7713972892362291}
# [TEST] Metric:None
# - Elapsed time: 1.14s , Time estimation in a fold: 0.95min
# [TRAIN] Epoch: 30, train loss: 0.424707 train auc: 0.802724
# [TRAIN] Metric:{'auc': 0.8027240827006077}
# [VALID] Epoch: 30, valid loss: 0.503415 valid auc: 0.792294
# [VALID] Metric:{'auc': 0.7922943330690528}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 40, train loss: 0.413190 train auc: 0.814709
# [TRAIN] Metric:{'auc': 0.8147091907224688}
# [VALID] Epoch: 40, valid loss: 0.495961 valid auc: 0.797618
# [VALID] Metric:{'auc': 0.7976176992486881}
# [TEST] Metric:None
# - Elapsed time: 0.92s , Time estimation in a fold: 0.77min
# [TRAIN] Epoch: 50, train loss: 0.403370 train auc: 0.827480
# [TRAIN] Metric:{'auc': 0.827479856704447}
# [VALID] Epoch: 50, valid loss: 0.494653 valid auc: 0.810945
# [VALID] Metric:{'auc': 0.8109449918828104}
# [TEST] Metric:None
# - Elapsed time: 0.97s , Time estimation in a fold: 0.81min
# 4 split, TR Score: 0.8247655552702687 VL Score: 0.8011099784800091
# Training in Fold: 5
# [TRAIN] Epoch: 1, train loss: 0.648565 train auc: 0.414689
# [TRAIN] Metric:{'auc': 0.414689016860458}
# [VALID] Epoch: 1, valid loss: 0.544768 valid auc: 0.558293
# [VALID] Metric:{'auc': 0.5582927473855098}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 10, train loss: 0.458916 train auc: 0.779178
# [TRAIN] Metric:{'auc': 0.7791777215354958}
# [VALID] Epoch: 10, valid loss: 0.510862 valid auc: 0.752312
# [VALID] Metric:{'auc': 0.7523124551666855}
# [TEST] Metric:None
# - Elapsed time: 0.94s , Time estimation in a fold: 0.78min
# [TRAIN] Epoch: 20, train loss: 0.426120 train auc: 0.805181
# [TRAIN] Metric:{'auc': 0.8051806070090924}
# [VALID] Epoch: 20, valid loss: 0.500682 valid auc: 0.786367
# [VALID] Metric:{'auc': 0.7863668969683241}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 30, train loss: 0.411329 train auc: 0.815756
# [TRAIN] Metric:{'auc': 0.8157555824540382}
# [VALID] Epoch: 30, valid loss: 0.500915 valid auc: 0.806452
# [VALID] Metric:{'auc': 0.8064522218446786}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 40, train loss: 0.400469 train auc: 0.827547
# [TRAIN] Metric:{'auc': 0.8275471029111494}
# [VALID] Epoch: 40, valid loss: 0.493712 valid auc: 0.810001
# [VALID] Metric:{'auc': 0.810001132631102}
# [TEST] Metric:None
# - Elapsed time: 1.19s , Time estimation in a fold: 0.99min
# [TRAIN] Epoch: 50, train loss: 0.390630 train auc: 0.840809
# [TRAIN] Metric:{'auc': 0.8408088699784406}
# [VALID] Epoch: 50, valid loss: 0.492305 valid auc: 0.823593
# [VALID] Metric:{'auc': 0.8235927058557029}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# 5 split, TR Score: 0.8379376607286227 VL Score: 0.8127949560161589
# TR avg is 0.8184 std is 0.0159; VL avg is 0.7926 std is 0.0164
