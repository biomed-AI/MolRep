# %%
import os
import sys
sys.path.append('../')
import numpy as np

from MolRep import MolRep
from MolRep.Utils.logger import Logger
from MolRep.Utils.config_from_dict import Config
from MolRep.Experiments.experiments import EndToEndExperiment

# %%
MODEL_CONFIG_DIR = '../MolRep/Configs' # Need to set! The directory of Model Configurations files, such as config_CMPNN.yml.
DATASET_DIR = '../MolRep/Datasets'     # Need to set! The directory of Datasets downloaded from Google Drive.
OUTPUT_DIR = '../Outputs/'

# Output file name
_CONFIG_BASE = 'config_'
_CONFIG_FILENAME = 'config_results.json'

# Args
_FOLDS = 5
MODEL_NAME = 'CMPNN'#'MolecularFingerprint' #'CMPNN'
DATASET_NAME = 'BBBP'

# %%
dataset_config, dataset, model_configurations, model_selector, exp_path = MolRep.construct_dataset(
        dataset_name = DATASET_NAME,
        model_name = MODEL_NAME,
        inner_k = _FOLDS,
        config_dir = MODEL_CONFIG_DIR,
        datasets_dir = DATASET_DIR,
        output_dir=OUTPUT_DIR
)

# %%
config_id = 0  # the idx of model config since there are more than 100 combinations of hyper-parameters.
KFOLD_FOLDER = os.path.join(exp_path, str(_FOLDS) + '_FOLD_MS')
exp_config_name = os.path.join(KFOLD_FOLDER, _CONFIG_BASE + str(config_id + 1))
config_filename = os.path.join(exp_config_name, _CONFIG_FILENAME)
if not os.path.exists(exp_config_name):
    os.makedirs(exp_config_name)

# %%
config = model_configurations[config_id]

# model configs could be change
# for example:
# config['device'] = 'cpu' or config['batch_size'] = 32

logger = Logger(str(os.path.join(exp_config_name, 'experiment.log')), mode='w')
logger.log('Configuration: ' + str(config))
# Out:
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': True}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}

# %%
k_fold_dict = {
    'config': config,
    'folds': [{} for _ in range(_FOLDS)],
    'avg_TR_score': 0.,
    'avg_VL_score': 0.,
    'std_TR_score': 0.,
    'std_VL_score': 0.
}

# %%
dataset_getter = MolRep.construct_dataloader(dataset)
for k in range(_FOLDS):
    logger.log(f"Training in Fold: {k+1}")
    dataset_getter.set_inner_k(k)

    fold_exp_folder = os.path.join(exp_config_name, 'FOLD_' + str(k + 1))
    # Create the experiment object which will be responsible for running a specific experiment
    experiment = EndToEndExperiment(config, dataset_config, fold_exp_folder)

    model_path = os.path.join(fold_exp_folder, f"{MODEL_NAME}_{DATASET_NAME}_fold_{k}.pt")
    training_score, validation_score, validation_loss = experiment.run_valid(dataset_getter, logger, other={'model_path': model_path})

    # print('training_score:', training_score, 'validation_score:',validation_score)
    logger.log(str(k+1) + ' split, TR Score: ' + str(training_score) +
                ' VL Score: ' + str(validation_score))

    k_fold_dict['folds'][k]['TR_score'] = training_score
    k_fold_dict['folds'][k]['VL_score'] = validation_score

tr_scores = np.array([k_fold_dict['folds'][k]['TR_score'] for k in range(_FOLDS)])
vl_scores = np.array([k_fold_dict['folds'][k]['VL_score'] for k in range(_FOLDS)])

k_fold_dict['avg_TR_score'] = tr_scores.mean()
k_fold_dict['std_TR_score'] = tr_scores.std()
k_fold_dict['avg_VL_score'] = vl_scores.mean()
k_fold_dict['std_VL_score'] = vl_scores.std()


log_str = f"TR avg is %.4f std is %.4f; VL avg is %.4f std is %.4f" % (
            k_fold_dict['avg_TR_score'], k_fold_dict['std_TR_score'], k_fold_dict['avg_VL_score'], k_fold_dict['std_VL_score']
        )
logger.log(log_str)
# Out:
# Training in Fold: 1
# [TRAIN] Epoch: 1, train loss: 0.635051 train auc: 0.493728
# [TRAIN] Metric:{'auc': 0.49372776290210174}
# [VALID] Epoch: 1, valid loss: 0.549092 valid auc: 0.598935
# [VALID] Metric:{'auc': 0.598935326764073}
# [TEST] Metric:None
# - Elapsed time: 12.1s , Time estimation in a fold: 6.05min
# [TRAIN] Epoch: 10, train loss: 0.353713 train auc: 0.887450
# [TRAIN] Metric:{'auc': 0.8874502276182208}
# [VALID] Epoch: 10, valid loss: 0.482229 valid auc: 0.891305
# [VALID] Metric:{'auc': 0.8913051685732625}
# [TEST] Metric:None
# - Elapsed time: 3.68s , Time estimation in a fold: 1.84min
# [TRAIN] Epoch: 20, train loss: 0.245127 train auc: 0.947639
# [TRAIN] Metric:{'auc': 0.9476386392628185}
# [VALID] Epoch: 20, valid loss: 0.447075 valid auc: 0.948050
# [VALID] Metric:{'auc': 0.9480499867859704}
# [TEST] Metric:None
# - Elapsed time: 2.98s , Time estimation in a fold: 1.49min
# [TRAIN] Epoch: 30, train loss: 0.158507 train auc: 0.977611
# [TRAIN] Metric:{'auc': 0.9776110886957089}
# [VALID] Epoch: 30, valid loss: 0.438360 valid auc: 0.956394
# [VALID] Metric:{'auc': 0.9563937025710725}
# [TEST] Metric:None
# - Elapsed time: 2.50s , Time estimation in a fold: 1.25min
# 1 split, TR Score: 0.9776110886957089 VL Score: 0.9563937025710725
# Training in Fold: 2
# [TRAIN] Epoch: 1, train loss: 0.574066 train auc: 0.532600
# [TRAIN] Metric:{'auc': 0.5326001459038909}
# [VALID] Epoch: 1, valid loss: 0.534032 valid auc: 0.724204
# [VALID] Metric:{'auc': 0.7242043266508098}
# [TEST] Metric:None
# - Elapsed time: 3.07s , Time estimation in a fold: 1.53min
# [TRAIN] Epoch: 10, train loss: 0.254162 train auc: 0.943660
# [TRAIN] Metric:{'auc': 0.9436599053662473}
# [VALID] Epoch: 10, valid loss: 0.449845 valid auc: 0.940386
# [VALID] Metric:{'auc': 0.9403858496620984}
# [TEST] Metric:None
# - Elapsed time: 2.95s , Time estimation in a fold: 1.47min
# [TRAIN] Epoch: 20, train loss: 0.144635 train auc: 0.981635
# [TRAIN] Metric:{'auc': 0.9816346533967486}
# [VALID] Epoch: 20, valid loss: 0.436589 valid auc: 0.953902
# [VALID] Metric:{'auc': 0.9539019141465624}
# [TEST] Metric:None
# - Elapsed time: 3.63s , Time estimation in a fold: 1.81min
# [TRAIN] Epoch: 30, train loss: 0.086790 train auc: 0.992538
# [TRAIN] Metric:{'auc': 0.9925377088198495}
# [VALID] Epoch: 30, valid loss: 0.435056 valid auc: 0.951788
# [VALID] Metric:{'auc': 0.9517876694227356}
# [TEST] Metric:None
# - Elapsed time: 2.83s , Time estimation in a fold: 1.41min
# 2 split, TR Score: 0.989008301849882 VL Score: 0.9537508966662892
# Training in Fold: 3
# [TRAIN] Epoch: 1, train loss: 0.566622 train auc: 0.546231
# [TRAIN] Metric:{'auc': 0.5462307482261266}
# [VALID] Epoch: 1, valid loss: 0.535466 valid auc: 0.666214
# [VALID] Metric:{'auc': 0.6662136142258467}
# [TEST] Metric:None
# - Elapsed time: 2.86s , Time estimation in a fold: 1.43min
# [TRAIN] Epoch: 10, train loss: 0.232497 train auc: 0.953466
# [TRAIN] Metric:{'auc': 0.9534656249617919}
# [VALID] Epoch: 10, valid loss: 0.442590 valid auc: 0.954921
# [VALID] Metric:{'auc': 0.9549212821384075}
# [TEST] Metric:None
# - Elapsed time: 3.15s , Time estimation in a fold: 1.57min
# [TRAIN] Epoch: 20, train loss: 0.118640 train auc: 0.987078
# [TRAIN] Metric:{'auc': 0.9870775206119813}
# [VALID] Epoch: 20, valid loss: 0.436000 valid auc: 0.959263
# [VALID] Metric:{'auc': 0.9592630346962662}
# [TEST] Metric:None
# - Elapsed time: 4.43s , Time estimation in a fold: 2.21min
# [TRAIN] Epoch: 30, train loss: 0.087178 train auc: 0.992456
# [TRAIN] Metric:{'auc': 0.9924561982662705}
# [VALID] Epoch: 30, valid loss: 0.434754 valid auc: 0.958357
# [VALID] Metric:{'auc': 0.9583569298146261}
# [TEST] Metric:None
# - Elapsed time: 3.80s , Time estimation in a fold: 1.90min
# 3 split, TR Score: 0.9870968793684561 VL Score: 0.9605844376486579
# Training in Fold: 4
# [TRAIN] Epoch: 1, train loss: 0.549786 train auc: 0.611386
# [TRAIN] Metric:{'auc': 0.61138620922944}
# [VALID] Epoch: 1, valid loss: 0.530119 valid auc: 0.742024
# [VALID] Metric:{'auc': 0.7420243893230641}
# [TEST] Metric:None
# - Elapsed time: 3.46s , Time estimation in a fold: 1.73min
# [TRAIN] Epoch: 10, train loss: 0.215341 train auc: 0.960111
# [TRAIN] Metric:{'auc': 0.9601107728423139}
# [VALID] Epoch: 10, valid loss: 0.441874 valid auc: 0.956507
# [VALID] Metric:{'auc': 0.9565069656812776}
# [TEST] Metric:None
# - Elapsed time: 3.83s , Time estimation in a fold: 1.91min
# [TRAIN] Epoch: 20, train loss: 0.103820 train auc: 0.989225
# [TRAIN] Metric:{'auc': 0.9892253236987859}
# [VALID] Epoch: 20, valid loss: 0.437972 valid auc: 0.954393
# [VALID] Metric:{'auc': 0.9543927209574509}
# [TEST] Metric:None
# - Elapsed time: 3.77s , Time estimation in a fold: 1.88min
# [TRAIN] Epoch: 30, train loss: 0.110404 train auc: 0.989636
# [TRAIN] Metric:{'auc': 0.9896359331124397}
# [VALID] Epoch: 30, valid loss: 0.437358 valid auc: 0.952203
# [VALID] Metric:{'auc': 0.9522029674934874}
# [TEST] Metric:None
# - Elapsed time: 3.94s , Time estimation in a fold: 1.97min
# 4 split, TR Score: 0.9938744818985439 VL Score: 0.9599426133574962
# Training in Fold: 5
# [TRAIN] Epoch: 1, train loss: 0.566563 train auc: 0.565942
# [TRAIN] Metric:{'auc': 0.56594203784535}
# [VALID] Epoch: 1, valid loss: 0.535114 valid auc: 0.671008
# [VALID] Metric:{'auc': 0.6710084192245254}
# [TEST] Metric:None
# - Elapsed time: 3.83s , Time estimation in a fold: 1.91min
# [TRAIN] Epoch: 10, train loss: 0.213054 train auc: 0.960437
# [TRAIN] Metric:{'auc': 0.9604368150566294}
# [VALID] Epoch: 10, valid loss: 0.441593 valid auc: 0.955563
# [VALID] Metric:{'auc': 0.9555631064295692}
# [TEST] Metric:None
# - Elapsed time: 3.89s , Time estimation in a fold: 1.94min
# [TRAIN] Epoch: 20, train loss: 0.106313 train auc: 0.989211
# [TRAIN] Metric:{'auc': 0.9892110593519096}
# [VALID] Epoch: 20, valid loss: 0.437661 valid auc: 0.956318
# [VALID] Metric:{'auc': 0.956318193830936}
# [TEST] Metric:None
# - Elapsed time: 4.34s , Time estimation in a fold: 2.17min
# [TRAIN] Epoch: 30, train loss: 0.166759 train auc: 0.978750
# [TRAIN] Metric:{'auc': 0.9787501986819743}
# [VALID] Epoch: 30, valid loss: 0.436027 valid auc: 0.957564
# [VALID] Metric:{'auc': 0.957564088043191}
# [TEST] Metric:None
# - Elapsed time: 2.41s , Time estimation in a fold: 1.20min
# 5 split, TR Score: 0.9919345307233655 VL Score: 0.9587722278853779
# TR avg is 0.9879 std is 0.0057; VL avg is 0.9579 std is 0.0025
