# %%
import os
import sys
sys.path.append('../')
import numpy as np

from MolRep import MolRep
from MolRep.Utils.logger import Logger
from MolRep.Utils.config_from_dict import Config
from MolRep.Experiments.experiments import EndToEndExperiment

# %%
MODEL_CONFIG_DIR = '../MolRep/Configs' # Need to set! The directory of Model Configurations files, such as config_CMPNN.yml.
DATASET_DIR = '../MolRep/Datasets'     # Need to set! The directory of Datasets downloaded from Google Drive.
OUTPUT_DIR = '../Outputs/'

# Output file name
_CONFIG_BASE = 'config_'
_CONFIG_FILENAME = 'config_results.json'

# Args
_FOLDS = 5
MODEL_NAME = 'MorganFP'#'MolecularFingerprint' #'CMPNN'
DATASET_NAME = 'BBBP'

# %%
dataset_config, dataset, model_configurations, model_selector, exp_path = MolRep.construct_dataset(
        dataset_name = DATASET_NAME,
        model_name = MODEL_NAME,
        inner_k = _FOLDS,
        config_dir = MODEL_CONFIG_DIR,
        datasets_dir = DATASET_DIR,
        output_dir=OUTPUT_DIR
)

# %%
config_id = 0  # the idx of model config since there are more than 100 combinations of hyper-parameters.
KFOLD_FOLDER = os.path.join(exp_path, str(_FOLDS) + '_FOLD_MS')
exp_config_name = os.path.join(KFOLD_FOLDER, _CONFIG_BASE + str(config_id + 1))
config_filename = os.path.join(exp_config_name, _CONFIG_FILENAME)
if not os.path.exists(exp_config_name):
    os.makedirs(exp_config_name)

# %%
config = model_configurations[config_id]

# model configs could be change
# for example:
# config['device'] = 'cpu' or config['batch_size'] = 32

logger = Logger(str(os.path.join(exp_config_name, 'experiment.log')), mode='w')
logger.log('Configuration: ' + str(config))
# Out:
# Configuration: {'model': 'MorganFP', 'device': 'cuda', 'batch_size': 32, 'learning_rate': 0.01, 'l2': 0.0, 'num_epochs': 50, 'num_lrs': 1, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'gradient_clipping': None, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': True}}, 'shuffle': True, 'hidden_units': 128}

# %%
k_fold_dict = {
    'config': config,
    'folds': [{} for _ in range(_FOLDS)],
    'avg_TR_score': 0.,
    'avg_VL_score': 0.,
    'std_TR_score': 0.,
    'std_VL_score': 0.
}

# %%
dataset_getter = MolRep.construct_dataloader(dataset)
for k in range(_FOLDS):
    logger.log(f"Training in Fold: {k+1}")
    dataset_getter.set_inner_k(k)

    fold_exp_folder = os.path.join(exp_config_name, 'FOLD_' + str(k + 1))
    # Create the experiment object which will be responsible for running a specific experiment
    experiment = EndToEndExperiment(config, dataset_config, fold_exp_folder)

    model_path = os.path.join(fold_exp_folder, f"{MODEL_NAME}_{DATASET_NAME}_fold_{k}.pt")
    training_score, validation_score, validation_loss = experiment.run_valid(dataset_getter, logger, other={'model_path': model_path})

    # print('training_score:', training_score, 'validation_score:',validation_score)
    logger.log(str(k+1) + ' split, TR Score: ' + str(training_score) +
                ' VL Score: ' + str(validation_score))

    k_fold_dict['folds'][k]['TR_score'] = training_score
    k_fold_dict['folds'][k]['VL_score'] = validation_score

tr_scores = np.array([k_fold_dict['folds'][k]['TR_score'] for k in range(_FOLDS)])
vl_scores = np.array([k_fold_dict['folds'][k]['VL_score'] for k in range(_FOLDS)])

k_fold_dict['avg_TR_score'] = tr_scores.mean()
k_fold_dict['std_TR_score'] = tr_scores.std()
k_fold_dict['avg_VL_score'] = vl_scores.mean()
k_fold_dict['std_VL_score'] = vl_scores.std()


log_str = f"TR avg is %.4f std is %.4f; VL avg is %.4f std is %.4f" % (
            k_fold_dict['avg_TR_score'], k_fold_dict['std_TR_score'], k_fold_dict['avg_VL_score'], k_fold_dict['std_VL_score']
        )
logger.log(log_str)
# Out:
# Training in Fold: 1
# [TRAIN] Epoch: 1, train loss: 0.692826 train auc: 0.486420
# [TRAIN] Metric:{'auc': 0.48642034177375115}
# [VALID] Epoch: 1, valid loss: 0.573312 valid auc: 0.495658
# [VALID] Metric:{'auc': 0.4956582474421414}
# [TEST] Metric:None
# - Elapsed time: 3.76s , Time estimation in a fold: 3.14min
# [TRAIN] Epoch: 10, train loss: 0.573786 train auc: 0.769187
# [TRAIN] Metric:{'auc': 0.7691865654305591}
# [VALID] Epoch: 10, valid loss: 0.546169 valid auc: 0.736399
# [VALID] Metric:{'auc': 0.7363989881828822}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 20, train loss: 0.453149 train auc: 0.869016
# [TRAIN] Metric:{'auc': 0.8690155970444274}
# [VALID] Epoch: 20, valid loss: 0.519444 valid auc: 0.779590
# [VALID] Metric:{'auc': 0.7795899875410579}
# [TEST] Metric:None
# - Elapsed time: 1.05s , Time estimation in a fold: 0.87min
# [TRAIN] Epoch: 30, train loss: 0.377302 train auc: 0.928631
# [TRAIN] Metric:{'auc': 0.928631397050133}
# [VALID] Epoch: 30, valid loss: 0.506011 valid auc: 0.807528
# [VALID] Metric:{'auc': 0.8075282213916262}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 40, train loss: 0.320482 train auc: 0.964165
# [TRAIN] Metric:{'auc': 0.9641649040009456}
# [VALID] Epoch: 40, valid loss: 0.499066 valid auc: 0.818779
# [VALID] Metric:{'auc': 0.8187790236719901}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 50, train loss: 0.277596 train auc: 0.982142
# [TRAIN] Metric:{'auc': 0.9821420565927774}
# [VALID] Epoch: 50, valid loss: 0.495431 valid auc: 0.817307
# [VALID] Metric:{'auc': 0.817306603239325}
# [TEST] Metric:None
# - Elapsed time: 1.28s , Time estimation in a fold: 1.07min
# 1 split, TR Score: 0.9821420565927774 VL Score: 0.817306603239325
# Training in Fold: 2
# [TRAIN] Epoch: 1, train loss: 0.670598 train auc: 0.571877
# [TRAIN] Metric:{'auc': 0.5718770250278155}
# [VALID] Epoch: 1, valid loss: 0.564163 valid auc: 0.687583
# [VALID] Metric:{'auc': 0.6875825876845245}
# [TEST] Metric:None
# - Elapsed time: 1.21s , Time estimation in a fold: 1.01min
# [TRAIN] Epoch: 10, train loss: 0.414368 train auc: 0.899483
# [TRAIN] Metric:{'auc': 0.8994832230903098}
# [VALID] Epoch: 10, valid loss: 0.511028 valid auc: 0.796693
# [VALID] Metric:{'auc': 0.7966927171820137}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 20, train loss: 0.318542 train auc: 0.965748
# [TRAIN] Metric:{'auc': 0.9657482465042161}
# [VALID] Epoch: 20, valid loss: 0.498501 valid auc: 0.817684
# [VALID] Metric:{'auc': 0.8176841469400083}
# [TEST] Metric:None
# - Elapsed time: 0.99s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 30, train loss: 0.264549 train auc: 0.986162
# [TRAIN] Metric:{'auc': 0.9861615457661381}
# [VALID] Epoch: 30, valid loss: 0.494198 valid auc: 0.816344
# [VALID] Metric:{'auc': 0.8163438668025824}
# [TEST] Metric:None
# - Elapsed time: 1.02s , Time estimation in a fold: 0.85min
# [TRAIN] Epoch: 40, train loss: 0.231993 train auc: 0.992714
# [TRAIN] Metric:{'auc': 0.9927139753919639}
# [VALID] Epoch: 40, valid loss: 0.492478 valid auc: 0.811039
# [VALID] Metric:{'auc': 0.8110393778079812}
# [TEST] Metric:None
# - Elapsed time: 1.25s , Time estimation in a fold: 1.04min
# [TRAIN] Epoch: 50, train loss: 0.212349 train auc: 0.995204
# [TRAIN] Metric:{'auc': 0.9952041228038001}
# [VALID] Epoch: 50, valid loss: 0.491687 valid auc: 0.805452
# [VALID] Metric:{'auc': 0.8054517310378677}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# 2 split, TR Score: 0.9952041228038001 VL Score: 0.8054517310378677
# Training in Fold: 3
# [TRAIN] Epoch: 1, train loss: 0.672600 train auc: 0.555779
# [TRAIN] Metric:{'auc': 0.5557786906959779}
# [VALID] Epoch: 1, valid loss: 0.562095 valid auc: 0.652886
# [VALID] Metric:{'auc': 0.6528863215917242}
# [TEST] Metric:None
# - Elapsed time: 0.99s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 10, train loss: 0.369204 train auc: 0.932910
# [TRAIN] Metric:{'auc': 0.9329096822311068}
# [VALID] Epoch: 10, valid loss: 0.503959 valid auc: 0.808246
# [VALID] Metric:{'auc': 0.8082455544229246}
# [TEST] Metric:None
# - Elapsed time: 0.96s , Time estimation in a fold: 0.80min
# [TRAIN] Epoch: 20, train loss: 0.278487 train auc: 0.981982
# [TRAIN] Metric:{'auc': 0.9819820921313787}
# [VALID] Epoch: 20, valid loss: 0.495109 valid auc: 0.816684
# [VALID] Metric:{'auc': 0.8166836561331974}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 30, train loss: 0.233663 train auc: 0.992215
# [TRAIN] Metric:{'auc': 0.9922147232512931}
# [VALID] Epoch: 30, valid loss: 0.492895 valid auc: 0.808850
# [VALID] Metric:{'auc': 0.8088496243440179}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 40, train loss: 0.210818 train auc: 0.995027
# [TRAIN] Metric:{'auc': 0.9950268373497659}
# [VALID] Epoch: 40, valid loss: 0.491873 valid auc: 0.804130
# [VALID] Metric:{'auc': 0.804130328085476}
# [TEST] Metric:None
# - Elapsed time: 0.97s , Time estimation in a fold: 0.81min
# [TRAIN] Epoch: 50, train loss: 0.197777 train auc: 0.995718
# [TRAIN] Metric:{'auc': 0.9957176392913474}
# [VALID] Epoch: 50, valid loss: 0.491522 valid auc: 0.800242
# [VALID] Metric:{'auc': 0.8002416279684373}
# [TEST] Metric:None
# - Elapsed time: 0.94s , Time estimation in a fold: 0.78min
# 3 split, TR Score: 0.9954945041509251 VL Score: 0.8023936270623325
# Training in Fold: 4
# [TRAIN] Epoch: 1, train loss: 0.693147 train auc: 0.500000
# [TRAIN] Metric:{'auc': 0.5}
# [VALID] Epoch: 1, valid loss: 0.573342 valid auc: 0.500000
# [VALID] Metric:{'auc': 0.5}
# [TEST] Metric:None
# - Elapsed time: 0.93s , Time estimation in a fold: 0.77min
# [TRAIN] Epoch: 10, train loss: 0.693147 train auc: 0.500000
# [TRAIN] Metric:{'auc': 0.5}
# [VALID] Epoch: 10, valid loss: 0.573342 valid auc: 0.500000
# [VALID] Metric:{'auc': 0.5}
# [TEST] Metric:None
# - Elapsed time: 0.97s , Time estimation in a fold: 0.81min
# [TRAIN] Epoch: 20, train loss: 0.693147 train auc: 0.500000
# [TRAIN] Metric:{'auc': 0.5}
# [VALID] Epoch: 20, valid loss: 0.573342 valid auc: 0.500000
# [VALID] Metric:{'auc': 0.5}
# [TEST] Metric:None
# - Elapsed time: 1.24s , Time estimation in a fold: 1.03min
# [TRAIN] Epoch: 30, train loss: 0.693147 train auc: 0.500000
# [TRAIN] Metric:{'auc': 0.5}
# [VALID] Epoch: 30, valid loss: 0.573342 valid auc: 0.500000
# [VALID] Metric:{'auc': 0.5}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 40, train loss: 0.693147 train auc: 0.500000
# [TRAIN] Metric:{'auc': 0.5}
# [VALID] Epoch: 40, valid loss: 0.573342 valid auc: 0.500000
# [VALID] Metric:{'auc': 0.5}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 50, train loss: 0.693147 train auc: 0.500000
# [TRAIN] Metric:{'auc': 0.5}
# [VALID] Epoch: 50, valid loss: 0.573342 valid auc: 0.500000
# [VALID] Metric:{'auc': 0.5}
# [TEST] Metric:None
# - Elapsed time: 0.96s , Time estimation in a fold: 0.80min
# 4 split, TR Score: 0.5 VL Score: 0.5
# Training in Fold: 5
# [TRAIN] Epoch: 1, train loss: 0.657349 train auc: 0.566252
# [TRAIN] Metric:{'auc': 0.56625177794895}
# [VALID] Epoch: 1, valid loss: 0.556225 valid auc: 0.715068
# [VALID] Metric:{'auc': 0.7150677690942727}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# [TRAIN] Epoch: 10, train loss: 0.336294 train auc: 0.953828
# [TRAIN] Metric:{'auc': 0.9538283469252181}
# [VALID] Epoch: 10, valid loss: 0.499313 valid auc: 0.823234
# [VALID] Metric:{'auc': 0.8232340393400535}
# [TEST] Metric:None
# - Elapsed time: 0.96s , Time estimation in a fold: 0.80min
# [TRAIN] Epoch: 20, train loss: 0.250949 train auc: 0.989350
# [TRAIN] Metric:{'auc': 0.9893496272929938}
# [VALID] Epoch: 20, valid loss: 0.493060 valid auc: 0.818552
# [VALID] Metric:{'auc': 0.8185524974515801}
# [TEST] Metric:None
# - Elapsed time: 0.98s , Time estimation in a fold: 0.82min
# [TRAIN] Epoch: 30, train loss: 0.215954 train auc: 0.994991
# [TRAIN] Metric:{'auc': 0.9949911764825752}
# [VALID] Epoch: 30, valid loss: 0.491589 valid auc: 0.809378
# [VALID] Metric:{'auc': 0.8093781855249744}
# [TEST] Metric:None
# - Elapsed time: 0.93s , Time estimation in a fold: 0.77min
# [TRAIN] Epoch: 40, train loss: 0.198718 train auc: 0.994413
# [TRAIN] Metric:{'auc': 0.9944134704340846}
# [VALID] Epoch: 40, valid loss: 0.490808 valid auc: 0.803262
# [VALID] Metric:{'auc': 0.8032619775739042}
# [TEST] Metric:None
# - Elapsed time: 1.16s , Time estimation in a fold: 0.97min
# [TRAIN] Epoch: 50, train loss: 0.190212 train auc: 0.994269
# [TRAIN] Metric:{'auc': 0.9942687892014819}
# [VALID] Epoch: 50, valid loss: 0.490262 valid auc: 0.800091
# [VALID] Metric:{'auc': 0.800090610488164}
# [TEST] Metric:None
# - Elapsed time: 0.95s , Time estimation in a fold: 0.79min
# 5 split, TR Score: 0.9941760709467858 VL Score: 0.800090610488164
# TR avg is 0.8934 std is 0.1968; VL avg is 0.7450 std is 0.1227
