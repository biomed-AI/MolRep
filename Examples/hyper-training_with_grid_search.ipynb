# %%
from MolRep import MolRep
from MolRep import EndToEnd_Experiments

# %%
# training with defined data

OUTPUT_DIR = '../Outputs/'
DATASET_DIR = '../MolRep/Datasets'
_CONFIG_BASE = 'config_'
_CONFIG_FILENAME = 'config_results.json'
_OUTER_FOLDS = 5
_INNER_FOLDS = 5

MODEL_NAME = 'CMPNN'
DATASET_NAME = 'BBBP'

config_file = f'../MolRep/Configs/config_{MODEL_NAME}.yml'

# %%
EndToEnd_Experiments.endtoend(config_file, DATASET_NAME,
                              outer_k=_OUTER_FOLDS, outer_processes=1,
                              inner_k=_INNER_FOLDS, inner_processes=1,
                              output_dir=OUTPUT_DIR,
                              datasets_dir=DATASET_DIR)
# Out:
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 3, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': True, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': True, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 50, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 300, 'bias': True, 'depth': 3, 'dropout': 0.0, 'activation': 'ReLU', 'undirected': False, 'ffn_hidden_size': 256, 'ffn_num_layers': 5, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
# ...
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_920/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_921/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_922/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_923/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_924/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_925/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_926/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_927/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_928/config_results.json'
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 64, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 256, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 30, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}[Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_929/config_results.json'
#
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_930/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_931/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_932/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_933/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_934/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_935/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_936/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_937/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_938/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_939/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_940/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_941/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_942/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_943/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_944/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_945/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_946/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_947/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_948/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_949/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_950/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_951/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_952/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_953/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_954/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_955/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_956/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_957/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_958/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_959/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_960/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_961/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_962/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_963/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_964/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_965/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_966/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_967/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_968/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_969/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_970/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_971/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_972/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_973/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_974/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_975/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_976/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_977/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_978/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_979/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_980/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_981/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_982/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_983/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_984/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_985/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_986/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_987/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_988/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_989/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_990/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_991/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_992/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_993/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_994/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_995/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_996/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_997/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_998/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_999/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1000/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1001/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1002/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1003/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1004/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1005/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1006/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1007/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1008/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1009/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1010/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1011/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1012/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1013/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1014/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1015/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1016/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1017/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1018/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1019/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1020/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1021/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1022/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1023/config_results.json'
# [Errno 2] No such file or directory: '../Outputs/CMPNN_BBBP_assessment/5_NESTED_CV/OUTER_FOLD_5/5_FOLD_MS/config_1024/config_results.json'
# Configuration: {'model': 'CMPNN', 'device': 'cuda', 'batch_size': 64, 'learning_rate': 0.0001, 'l2': 0, 'hidden_size': 256, 'bias': False, 'depth': 2, 'dropout': 0.1, 'activation': 'ReLU', 'undirected': True, 'ffn_hidden_size': 512, 'ffn_num_layers': 2, 'atom_messages': False, 'no_cache': False, 'optimizer': 'Adam', 'scheduler': {'class': 'NoamLR', 'args': {'warmup_epochs': [2.0], 'step_size': 10, 'max_lr': [0.0001], 'init_lr': [1e-05], 'final_lr': [1e-05]}}, 'early_stopper': {'class': 'Patience', 'args': {'patience': 500, 'use_loss': False}}, 'gradient_clipping': None, 'num_epochs': 100, 'num_lrs': 1, 'features_only': False, 'atom_descriptors': 'None', 'use_input_features': False, 'shuffle': True}
