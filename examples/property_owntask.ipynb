# %%
# !python ../train.py --options dataset_name=bbbp \
                              dataset_path=cache/ogbg_molbbbp/mapping/mol.csv \
                              task_type=classification \
                              smiles_column=smiles \
                              target_columns=p_np \
                    --job-id test_owndataset
# Out:
# Missing Model name or Model has not been registered.
# Using the default gnn_model: GIN.
# {
#     "run": {
#         "task": "property_prediction",
#         "device": "cuda",
#         "distributed": false,
#         "evaluate_only": false,
#         "type": "train_test",
#         "optimizer": "Adam",
#         "lr_sched": "linear_warmup_step_lr",
#         "init_lr": 0.001,
#         "max_lr": 0.001,
#         "min_lr": 1e-06,
#         "step_size": 10,
#         "warmup_epochs": 2.0,
#         "weight_decay": 0.1,
#         "num_epochs": 200,
#         "earlystopping": false,
#         "batch_size": 32,
#         "seed": 42,
#         "num_workers": 4,
#         "class_balance": false
#     },
#     "model": {
#         "name": "gin",
#         "model_type": "default",
#         "finetuned": "",
#         "pretrained": "",
#         "num_layers": 5,
#         "hidden_size": 300,
#         "JK": "last",
#         "aggregation": "sum",
#         "dropout": 0.5
#     },
# ...
