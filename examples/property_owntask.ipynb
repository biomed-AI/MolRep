# %%
# !python ../train.py --options dataset_name=bbbp \
                              dataset_path=cache/ogbg_molbbbp/mapping/mol.csv \
                              task_type=classification \
                              smiles_column=smiles \
                              target_columns=p_np
# Out:
# Missing Model name or Model has not been registered.
# Using the default gnn_model: GIN.
# {
#     "run": {
#         "task": "property_prediction",
#         "device": "cuda",
#         "distributed": false,
#         "evaluate_only": false,
#         "type": "train_test",
#         "optimizer": "Adam",
#         "lr_sched": "linear_warmup_step_lr",
#         "init_lr": 0.001,
#         "max_lr": 0.001,
#         "min_lr": 1e-06,
#         "step_size": 10,
#         "warmup_epochs": 2.0,
#         "weight_decay": 0.1,
#         "num_epochs": 200,
#         "earlystopping": false,
#         "batch_size": 32,
#         "seed": 42,
#         "num_workers": 4,
#         "class_balance": false
#     },
#     "model": {
#         "name": "gin",
#         "model_type": "default",
#         "finetuned": "",
#         "pretrained": "",
#         "num_layers": 5,
#         "hidden_size": 300,
#         "JK": "last",
#         "aggregation": "sum",
#         "dropout": 0.5
#     },
#     "datasets": {
#         "dim_target": 1,
#         "feature": "full",
#         "metric_type": "auc",
#         "multiclass_num_classes": 1,
#         "name": "bbbp",
#         "num_tasks": 1,
#         "smiles_column": "smiles",
#         "split_type": "random",
#         "storage": [
#             "cache/ogbg_molbbbp/mapping/mol.csv"
#         ],
#         "target_columns": [
#             "p_np"
#         ],
#         "task": "property_prediction",
#         "task_type": "classification",
#         "dim_features": 9,
#         "max_num_nodes": 132,
#         "dim_edge_features": 3
#     }
# }
#
# Start training
# Training on Epoch:0
# {"train_auc": 0.636002241602746, "train_loss": 2.4270219826245145, "train_epoch": 0}
#
# Evaluating on test.
# Saving checkpoint at epoch 0 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.7266679742407897, "test_loss": 0.7354212590292388, "test_best_epoch": 0}
#
# Training on Epoch:1
# {"train_auc": 0.7560470226323885, "train_loss": 0.6371388552307279, "train_epoch": 1}
#
# Evaluating on test.
# {"test_auc": 0.6917720898303421, "test_loss": 0.9827461663414451, "test_best_epoch": 0}
#
# Training on Epoch:2
# {"train_auc": 0.7714996143517943, "train_loss": 0.5907317219447096, "train_epoch": 2}
#
# Evaluating on test.
# Saving checkpoint at epoch 2 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.798306691510575, "test_loss": 0.5704423767678878, "test_best_epoch": 2}
#
# Training on Epoch:3
# {"train_auc": 0.7949362118859402, "train_loss": 0.4621393085622407, "train_epoch": 3}
#
# Evaluating on test.
# Saving checkpoint at epoch 3 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.8079173613154196, "test_loss": 0.9619105236203063, "test_best_epoch": 3}
#
# Training on Epoch:4
# {"train_auc": 0.807454178994164, "train_loss": 0.5033980066391824, "train_epoch": 4}
#
# Evaluating on test.
# {"test_auc": 0.7823869765617338, "test_loss": 0.5142297794421514, "test_best_epoch": 3}
#
# Training on Epoch:5
# {"train_auc": 0.8218721420127688, "train_loss": 0.42747162632383795, "train_epoch": 5}
#
# Evaluating on test.
# {"test_auc": 0.8056291065999803, "test_loss": 0.4427776663911109, "test_best_epoch": 3}
#
# Training on Epoch:6
# {"train_auc": 0.8049483629971436, "train_loss": 0.43559251103497665, "train_epoch": 6}
#
# Evaluating on test.
# Saving checkpoint at epoch 6 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.8370435749076526, "test_loss": 0.4358801882640988, "test_best_epoch": 6}
#
# Training on Epoch:7
# {"train_auc": 0.8447151020408163, "train_loss": 0.3975646479739359, "train_epoch": 7}
#
# Evaluating on test.
# Saving checkpoint at epoch 7 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.8378281193815174, "test_loss": 0.4187275375805649, "test_best_epoch": 7}
#
# Training on Epoch:8
# {"train_auc": 0.8513654421768708, "train_loss": 0.3775872570250679, "train_epoch": 8}
#
# Evaluating on test.
# Saving checkpoint at epoch 8 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.8480271975417606, "test_loss": 0.4489916031267129, "test_best_epoch": 8}
#
# Training on Epoch:9
# {"train_auc": 0.8535953206542678, "train_loss": 0.36919604423658603, "train_epoch": 9}
#
# Evaluating on test.
# {"test_auc": 0.8400509953908013, "test_loss": 0.5606501838740181, "test_best_epoch": 8}
#
# Training on Epoch:10
# {"train_auc": 0.8635254421768708, "train_loss": 0.3734116039708814, "train_epoch": 10}
#
# Evaluating on test.
# {"test_auc": 0.8117747049785884, "test_loss": 0.4289747073369868, "test_best_epoch": 8}
#
# Training on Epoch:11
# {"train_auc": 0.8674477251234632, "train_loss": 0.3524545100040775, "train_epoch": 11}
#
# Evaluating on test.
# Saving checkpoint at epoch 11 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.8526363963257167, "test_loss": 0.4631533482495476, "test_best_epoch": 11}
#
# Training on Epoch:12
# {"train_auc": 0.8715741129907884, "train_loss": 0.3432208455317887, "train_epoch": 12}
#
# Evaluating on test.
# {"test_auc": 0.7822235297963454, "test_loss": 0.4911794481324215, "test_best_epoch": 11}
#
# Training on Epoch:13
# {"train_auc": 0.8793869941593658, "train_loss": 0.33874754610418323, "train_epoch": 13}
#
# Evaluating on test.
# {"test_auc": 0.8025563074106765, "test_loss": 0.517333090597508, "test_best_epoch": 11}
#
# Training on Epoch:14
# {"train_auc": 0.8754678053929564, "train_loss": 0.3376134124582783, "train_epoch": 14}
#
# Evaluating on test.
# {"test_auc": 0.8139322022817168, "test_loss": 0.4445033050050922, "test_best_epoch": 11}
#
# Training on Epoch:15
# {"train_auc": 0.8827542055319213, "train_loss": 0.3388383398751844, "train_epoch": 15}
#
# Evaluating on test.
# Saving checkpoint at epoch 15 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.8750612925370207, "test_loss": 0.4785219290677239, "test_best_epoch": 15}
#
# Training on Epoch:16
# {"train_auc": 0.8844896141977676, "train_loss": 0.3296419645949129, "train_epoch": 16}
#
# Evaluating on test.
# {"test_auc": 0.8663005459121964, "test_loss": 0.41066253944939257, "test_best_epoch": 15}
#
# Training on Epoch:17
# {"train_auc": 0.8914517015467021, "train_loss": 0.3301304388017029, "train_epoch": 17}
#
# Evaluating on test.
# Saving checkpoint at epoch 17 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# {"test_auc": 0.8997417541106862, "test_loss": 0.3614162165744632, "test_best_epoch": 17}
#
# Training on Epoch:18
# {"train_auc": 0.9026631509558338, "train_loss": 0.30797521107625114, "train_epoch": 18}
#
# Evaluating on test.
# {"test_auc": 0.8755189434801086, "test_loss": 0.4023022993522532, "test_best_epoch": 17}
#
# Training on Epoch:19
# {"train_auc": 0.8951998269499268, "train_loss": 0.3165160038221255, "train_epoch": 19}
#
# Evaluating on test.
# {"test_auc": 0.8587493053512472, "test_loss": 0.41015921503889796, "test_best_epoch": 17}
#
# Training on Epoch:20
# {"train_auc": 0.9005474829931972, "train_loss": 0.30728655194739196, "train_epoch": 20}
#
# Evaluating on test.
# {"test_auc": 0.8887908208296558, "test_loss": 0.36590322150903587, "test_best_epoch": 17}
#
# Training on Epoch:21
# {"train_auc": 0.9127679415782285, "train_loss": 0.29877288790292933, "train_epoch": 21}
#
# Evaluating on test.
# {"test_auc": 0.873819097120068, "test_loss": 0.37328676207392825, "test_best_epoch": 17}
#
# Training on Epoch:22
# {"train_auc": 0.8984908730828869, "train_loss": 0.3112231588743714, "train_epoch": 22}
#
# Evaluating on test.
# {"test_auc": 0.8332189205975614, "test_loss": 0.42459427433855396, "test_best_epoch": 17}
#
# Training on Epoch:23
# {"train_auc": 0.9004212244897959, "train_loss": 0.3058987181293387, "train_epoch": 23}
#
# Evaluating on test.
# {"test_auc": 0.8757477689516524, "test_loss": 0.38539620152875487, "test_best_epoch": 17}
#
# Training on Epoch:24
# {"train_auc": 0.9106248467654372, "train_loss": 0.30358849530714116, "train_epoch": 24}
#
# Evaluating on test.
# {"test_auc": 0.8731326207054362, "test_loss": 0.39004751221806394, "test_best_epoch": 17}
#
# Training on Epoch:25
# {"train_auc": 0.90852715199555, "train_loss": 0.299171505933302, "train_epoch": 25}
#
# Evaluating on test.
# {"test_auc": 0.8792455297309666, "test_loss": 0.3781055472060746, "test_best_epoch": 17}
#
# Training on Epoch:26
# {"train_auc": 0.9149597403843637, "train_loss": 0.2852716270507588, "train_epoch": 26}
#
# Evaluating on test.
# {"test_auc": 0.8753554967147201, "test_loss": 0.4307146706417495, "test_best_epoch": 17}
#
# Training on Epoch:27
# {"train_auc": 0.9074423203691495, "train_loss": 0.2921241735988128, "train_epoch": 27}
#
# Evaluating on test.
# {"test_auc": 0.8837893498087673, "test_loss": 0.3995721720012964, "test_best_epoch": 17}
#
# Training on Epoch:28
# {"train_auc": 0.9179170189939936, "train_loss": 0.2882300797304005, "train_epoch": 28}
#
# Evaluating on test.
# {"test_auc": 0.8307508744401948, "test_loss": 0.5662387892896054, "test_best_epoch": 17}
#
# Training on Epoch:29
# {"train_auc": 0.9083102040816325, "train_loss": 0.3011406308518532, "train_epoch": 29}
#
# Evaluating on test.
# {"test_auc": 0.8457225981497827, "test_loss": 0.4473251811429566, "test_best_epoch": 17}
#
# Training on Epoch:30
# {"train_auc": 0.9092353328938694, "train_loss": 0.30272595038960715, "train_epoch": 30}
#
# Evaluating on test.
# {"test_auc": 0.8565918080481187, "test_loss": 0.4155239229108773, "test_best_epoch": 17}
#
# Training on Epoch:31
# {"train_auc": 0.9241485696056775, "train_loss": 0.2703988189568628, "train_epoch": 31}
#
# Evaluating on test.
# {"test_auc": 0.886894838351149, "test_loss": 0.3672470307233287, "test_best_epoch": 17}
#
# Training on Epoch:32
# {"train_auc": 0.92576525520935, "train_loss": 0.26687467076309174, "train_epoch": 32}
#
# Evaluating on test.
# {"test_auc": 0.8679677029191593, "test_loss": 0.43489689190013736, "test_best_epoch": 17}
#
# Training on Epoch:33
# {"train_auc": 0.9207165556552234, "train_loss": 0.27934567903463714, "train_epoch": 33}
#
# Evaluating on test.
# {"test_auc": 0.8842796901049329, "test_loss": 0.3885190223946291, "test_best_epoch": 17}
#
# Training on Epoch:34
# {"train_auc": 0.9245361202467046, "train_loss": 0.2772341713007793, "train_epoch": 34}
#
# Evaluating on test.
# {"test_auc": 0.8710078127553855, "test_loss": 0.40612761588657603, "test_best_epoch": 17}
#
# Training on Epoch:35
# {"train_auc": 0.9277235772357724, "train_loss": 0.26751712258793253, "train_epoch": 35}
#
# Evaluating on test.
# {"test_auc": 0.8970939165113923, "test_loss": 0.38247904356788187, "test_best_epoch": 17}
#
# Training on Epoch:36
# {"train_auc": 0.9272719696288483, "train_loss": 0.2711092862960095, "train_epoch": 36}
#
# Evaluating on test.
# {"test_auc": 0.827988624105129, "test_loss": 0.4444005512723736, "test_best_epoch": 17}
#
# Training on Epoch:37
# {"train_auc": 0.9202221683261557, "train_loss": 0.27745588099130597, "train_epoch": 37}
#
# Evaluating on test.
# {"test_auc": 0.8650910398483214, "test_loss": 0.42726748334426506, "test_best_epoch": 17}
#
# Early Stopping.
# Loading trained model from Epoch: best
#
# Loading checkpoint from /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/checkpoint_best.pth.
# Evaluating on test.
# {"test_auc": 0.8997417541106862, "test_loss": 0.36141619729060753}
#
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/20230626_004456/result/test_predictions.pth.
# Training time 0:01:27
