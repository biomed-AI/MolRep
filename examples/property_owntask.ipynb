# %%
# %run ../train.py --options dataset_name=bbbp \
                           dataset_path=cache/ogbg_molbbbp/mapping/mol.csv \
                           task_type=classification \
                           smiles_column=smiles \
                           target_columns=p_np \
                 --job-id test_owndataset
# Out:
# Missing Model name or Model has not been registered.
# Using the default gnn_model: GIN.
# {
#     "run": {
#         "task": "property_prediction",
#         "device": "cuda",
#         "distributed": false,
#         "evaluate_only": false,
#         "type": "train_test",
#         "optimizer": "Adam",
#         "lr_sched": "linear_warmup_step_lr",
#         "init_lr": 0.001,
#         "max_lr": 0.001,
#         "min_lr": 1e-06,
#         "step_size": 10,
#         "warmup_epochs": 2.0,
#         "weight_decay": 0.1,
#         "num_epochs": 200,
#         "earlystopping": false,
#         "batch_size": 32,
#         "seed": 42,
#         "num_workers": 4,
#         "class_balance": false
#     },
#     "model": {
#         "name": "gin",
#         "model_type": "default",
#         "finetuned": "",
#         "pretrained": "",
#         "num_layers": 5,
#         "hidden_size": 300,
#         "JK": "last",
#         "aggregation": "sum",
#         "dropout": 0.5
#     },
#     "datasets": {
#         "dim_target": 1,
#         "feature": "full",
#         "metric_type": "auc",
#         "multiclass_num_classes": 1,
#         "name": "bbbp",
#         "num_tasks": 1,
#         "smiles_column": "smiles",
#         "split_type": "random",
#         "storage": [
#             "cache/ogbg_molbbbp/mapping/mol.csv"
#         ],
#         "target_columns": [
#             "p_np"
#         ],
#         "task": "property_prediction",
#         "task_type": "classification",
#         "dim_features": 9,
#         "max_num_nodes": 132,
#         "dim_edge_features": 3
#     }
# }
#
# Start training
# Training on Epoch:0
# {"train_auc": 0.6478494623655915, "train_loss": 2.407128639267969, "train_epoch": 0}
#
# Evaluating on test.
# Saving checkpoint at epoch 0 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.7392370304991664, "test_loss": 0.6120600618568122, "test_best_epoch": 0}
#
# Training on Epoch:1
# {"train_auc": 0.7825071412876291, "train_loss": 0.5059181619172882, "train_epoch": 1}
#
# Evaluating on test.
# Saving checkpoint at epoch 1 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.7753914550031055, "test_loss": 0.49855900570458056, "test_best_epoch": 1}
#
# Training on Epoch:2
# {"train_auc": 0.7827325742727855, "train_loss": 0.5157257471254163, "train_epoch": 2}
#
# Evaluating on test.
# Saving checkpoint at epoch 2 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.7901016638880716, "test_loss": 0.5500733595268399, "test_best_epoch": 2}
#
# Training on Epoch:3
# {"train_auc": 0.7837688805759457, "train_loss": 0.5311013455043023, "train_epoch": 3}
#
# Evaluating on test.
# {"test_auc": 0.7696871628910463, "test_loss": 1.7889720330051346, "test_best_epoch": 2}
#
# Training on Epoch:4
# {"train_auc": 0.7868273243866225, "train_loss": 0.536542477891315, "train_epoch": 4}
#
# Evaluating on test.
# Saving checkpoint at epoch 4 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.7928802588996764, "test_loss": 0.5979876842568902, "test_best_epoch": 4}
#
# Training on Epoch:5
# {"train_auc": 0.8074585653534638, "train_loss": 0.4429147166024681, "train_epoch": 5}
#
# Evaluating on test.
# Saving checkpoint at epoch 5 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.8294269556405478, "test_loss": 0.437740903859045, "test_best_epoch": 5}
#
# Training on Epoch:6
# {"train_auc": 0.8213447593935398, "train_loss": 0.40425257826056094, "train_epoch": 6}
#
# Evaluating on test.
# Saving checkpoint at epoch 6 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.8419796672223855, "test_loss": 0.509482906145208, "test_best_epoch": 6}
#
# Training on Epoch:7
# {"train_auc": 0.8519902040816326, "train_loss": 0.38071888023764716, "train_epoch": 7}
#
# Evaluating on test.
# {"test_auc": 0.8173972737079533, "test_loss": 0.4403918706903271, "test_best_epoch": 6}
#
# Training on Epoch:8
# {"train_auc": 0.8550204081632653, "train_loss": 0.37245095485123586, "train_epoch": 8}
#
# Evaluating on test.
# Saving checkpoint at epoch 8 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.8486809846033148, "test_loss": 0.4811815292227502, "test_best_epoch": 8}
#
# Training on Epoch:9
# {"train_auc": 0.8668676228503379, "train_loss": 0.3701917077046388, "train_epoch": 9}
#
# Evaluating on test.
# {"test_auc": 0.8350822137229904, "test_loss": 0.4803955812080234, "test_best_epoch": 8}
#
# Training on Epoch:10
# {"train_auc": 0.8556778231292517, "train_loss": 0.36793787270364114, "train_epoch": 10}
#
# Evaluating on test.
# {"test_auc": 0.7931090843712203, "test_loss": 0.443419227997462, "test_best_epoch": 8}
#
# Training on Epoch:11
# {"train_auc": 0.8681350915904873, "train_loss": 0.3539626409786746, "train_epoch": 11}
#
# Evaluating on test.
# Saving checkpoint at epoch 11 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.8591415775881797, "test_loss": 0.40917180390918956, "test_best_epoch": 11}
#
# Training on Epoch:12
# {"train_auc": 0.8724891422366993, "train_loss": 0.34440854924504266, "train_epoch": 12}
#
# Evaluating on test.
# {"test_auc": 0.8148148148148148, "test_loss": 0.4968807673921772, "test_best_epoch": 11}
#
# Training on Epoch:13
# {"train_auc": 0.8908770511750799, "train_loss": 0.32062619599296155, "train_epoch": 13}
#
# Evaluating on test.
# {"test_auc": 0.8329574057729398, "test_loss": 0.45187439900987286, "test_best_epoch": 11}
#
# Training on Epoch:14
# {"train_auc": 0.8834433966379077, "train_loss": 0.33352880898901904, "train_epoch": 14}
#
# Evaluating on test.
# {"test_auc": 0.8250792716812134, "test_loss": 0.4327728701572792, "test_best_epoch": 11}
#
# Training on Epoch:15
# {"train_auc": 0.8889639063869024, "train_loss": 0.33169522452105926, "train_epoch": 15}
#
# Evaluating on test.
# Saving checkpoint at epoch 15 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.874145990650845, "test_loss": 0.42130814989407855, "test_best_epoch": 15}
#
# Training on Epoch:16
# {"train_auc": 0.8835114560739012, "train_loss": 0.32904010254645333, "train_epoch": 16}
#
# Evaluating on test.
# {"test_auc": 0.8607760452420647, "test_loss": 0.3875197002700731, "test_best_epoch": 15}
#
# Training on Epoch:17
# {"train_auc": 0.8895630326874928, "train_loss": 0.330405501921728, "train_epoch": 17}
#
# Evaluating on test.
# Saving checkpoint at epoch 17 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.8891830930665883, "test_loss": 0.38607365769498486, "test_best_epoch": 17}
#
# Training on Epoch:18
# {"train_auc": 0.9016304108987035, "train_loss": 0.31130908150968195, "train_epoch": 18}
#
# Evaluating on test.
# Saving checkpoint at epoch 18 to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# {"test_auc": 0.8949364192082638, "test_loss": 0.3553268187770657, "test_best_epoch": 18}
#
# Training on Epoch:19
# {"train_auc": 0.8938189223262999, "train_loss": 0.3161945313781701, "train_epoch": 19}
#
# Evaluating on test.
# {"test_auc": 0.8729364845869702, "test_loss": 0.38414427491964076, "test_best_epoch": 18}
#
# Training on Epoch:20
# {"train_auc": 0.9084691156462584, "train_loss": 0.29523695677354395, "train_epoch": 20}
#
# Evaluating on test.
# {"test_auc": 0.866137099146808, "test_loss": 0.4148235101910198, "test_best_epoch": 18}
#
# Training on Epoch:21
# {"train_auc": 0.9119360968092186, "train_loss": 0.29989195425476783, "train_epoch": 21}
#
# Evaluating on test.
# {"test_auc": 0.8612336961851524, "test_loss": 0.3812779299184388, "test_best_epoch": 18}
#
# Training on Epoch:22
# {"train_auc": 0.8991005770255659, "train_loss": 0.30304901633505293, "train_epoch": 22}
#
# Evaluating on test.
# {"test_auc": 0.8368147494361087, "test_loss": 0.4472151807710236, "test_best_epoch": 18}
#
# Training on Epoch:23
# {"train_auc": 0.9111880272108843, "train_loss": 0.2950682697085644, "train_epoch": 23}
#
# Evaluating on test.
# {"test_auc": 0.8763034879539735, "test_loss": 0.3926510267397937, "test_best_epoch": 18}
#
# Training on Epoch:24
# {"train_auc": 0.9068684109138034, "train_loss": 0.31013432022693477, "train_epoch": 24}
#
# Evaluating on test.
# {"test_auc": 0.8534209407995815, "test_loss": 0.421678517963372, "test_best_epoch": 18}
#
# Training on Epoch:25
# {"train_auc": 0.9041488492560144, "train_loss": 0.3040308975720245, "train_epoch": 25}
#
# Evaluating on test.
# {"test_auc": 0.8635709849302082, "test_loss": 0.47297275358555363, "test_best_epoch": 18}
#
# Training on Epoch:26
# {"train_auc": 0.9103318474060245, "train_loss": 0.290308349195395, "train_epoch": 26}
#
# Evaluating on test.
# {"test_auc": 0.8691445196299565, "test_loss": 0.46154628869365244, "test_best_epoch": 18}
#
# Training on Epoch:27
# {"train_auc": 0.8998813447593935, "train_loss": 0.3042537671959817, "train_epoch": 27}
#
# Evaluating on test.
# {"test_auc": 0.863162368016737, "test_loss": 0.40895067535194696, "test_best_epoch": 18}
#
# Training on Epoch:28
# {"train_auc": 0.9150022614498187, "train_loss": 0.2926597399334466, "train_epoch": 28}
#
# Evaluating on test.
# {"test_auc": 0.8641103592559902, "test_loss": 0.42787862291523054, "test_best_epoch": 18}
#
# Training on Epoch:29
# {"train_auc": 0.9132038095238094, "train_loss": 0.2925848006325072, "train_epoch": 29}
#
# Evaluating on test.
# {"test_auc": 0.8674446732699159, "test_loss": 0.40901780888146044, "test_best_epoch": 18}
#
# Training on Epoch:30
# {"train_auc": 0.9179608877169854, "train_loss": 0.2799785914850849, "train_epoch": 30}
#
# Evaluating on test.
# {"test_auc": 0.8514268902618418, "test_loss": 0.39471927285194397, "test_best_epoch": 18}
#
# Training on Epoch:31
# {"train_auc": 0.9258615905311894, "train_loss": 0.26817902431102125, "train_epoch": 31}
#
# Evaluating on test.
# {"test_auc": 0.8677061880945375, "test_loss": 0.4077031124456256, "test_best_epoch": 18}
#
# Training on Epoch:32
# {"train_auc": 0.920109044892194, "train_loss": 0.28149258586104703, "train_epoch": 32}
#
# Evaluating on test.
# {"test_auc": 0.8886273740642673, "test_loss": 0.37870998329976024, "test_best_epoch": 18}
#
# Training on Epoch:33
# {"train_auc": 0.9316912266234465, "train_loss": 0.2643820732228965, "train_epoch": 33}
#
# Evaluating on test.
# {"test_auc": 0.8702559576345985, "test_loss": 0.42233917993657727, "test_best_epoch": 18}
#
# Training on Epoch:34
# {"train_auc": 0.9253496000209367, "train_loss": 0.27148795756440014, "train_epoch": 34}
#
# Evaluating on test.
# {"test_auc": 0.8758785263639632, "test_loss": 0.38601817833442315, "test_best_epoch": 18}
#
# Training on Epoch:35
# {"train_auc": 0.9261063502526918, "train_loss": 0.2692283003846244, "train_epoch": 35}
#
# Evaluating on test.
# {"test_auc": 0.8915040371351051, "test_loss": 0.39170391156392936, "test_best_epoch": 18}
#
# Training on Epoch:36
# {"train_auc": 0.9237453367517694, "train_loss": 0.271663329266537, "train_epoch": 36}
#
# Evaluating on test.
# {"test_auc": 0.7926841227812101, "test_loss": 0.5522078240618986, "test_best_epoch": 18}
#
# Training on Epoch:37
# {"train_auc": 0.9241704193623803, "train_loss": 0.27253102525328654, "train_epoch": 37}
#
# Evaluating on test.
# {"test_auc": 0.8841816220456997, "test_loss": 0.3795241088259454, "test_best_epoch": 18}
#
# Training on Epoch:38
# {"train_auc": 0.9260569481027899, "train_loss": 0.2752059421094921, "train_epoch": 38}
#
# Evaluating on test.
# {"test_auc": 0.8560524337223366, "test_loss": 0.5199695860638338, "test_best_epoch": 18}
#
# Early Stopping.
# Loading trained model from Epoch: best
#
# Loading checkpoint from /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/checkpoint_best.pth.
# Evaluating on test.
# {"test_auc": 0.8949364192082638, "test_loss": 0.3553268234519398}
#
# Saving test predictions to /data/user/raojh/worksapce/MolRep-v2/outputs/property_prediction/gin_bbbp/test_owndataset/result/test_predictions.pth.
# Training time 0:01:36
